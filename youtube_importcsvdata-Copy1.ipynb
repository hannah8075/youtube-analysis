# %%
import pandas as pd
import os
import csv
from config import api_key
import requests
import json
from pprint import pprint

# %%
csvpath = os.path.join("youtube_video_data.csv")
youtube_data_df = pd.read_csv(csvpath)
youtube_data_df
# Out:
#           video_id trending_date  \
# 0      2kyS6SvSYSE      17.14.11
# 1      1ZAPwfrtAFY      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      puqaWrEC7tY      17.14.11
# 4      d380meD0W0M      17.14.11
# ...            ...           ...
# 40944  BZt0qjTWNhw      18.14.06
# 40945  1h7KV2sjUWY      18.14.06
# 40946  D6Oy4LfoqsU      18.14.06
# 40947  oV0zkMe1K8s      18.14.06
# 40948  ooyjaVdt-jA      18.14.06
#
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 40944                       The Cat Who Caught the Laser
# 40945                         True Facts : Ant Mutualism
# 40946  I GAVE SAFIYA NYGAARD A PERFECT HAIR MAKEOVER ...
# 40947                How Black Panther Should Have Ended
# 40948  Official Call of Duty®: Black Ops 4 — Multipla...
#
#                   channel_title  category_id              publish_time  \
# 0                  CaseyNeistat           22  2017-11-13T17:13:01.000Z
# 1               LastWeekTonight           24  2017-11-13T07:30:00.000Z
# 2                  Rudy Mancuso           23  2017-11-12T19:05:24.000Z
# 3         Good Mythical Morning           24  2017-11-13T11:00:04.000Z
# 4                      nigahiga           24  2017-11-12T18:01:41.000Z
# ...                         ...          ...                       ...
# 40944             AaronsAnimals           15  2018-05-18T13:00:04.000Z
# 40945                  zefrank1           22  2018-05-18T01:00:06.000Z
# 40946                Brad Mondo           24  2018-05-18T17:34:22.000Z
# 40947  How It Should Have Ended            1  2018-05-17T17:00:04.000Z
# 40948              Call of Duty           20  2018-05-17T17:09:38.000Z
#
#                                                     tags     views   likes  \
# 0                                        SHANtell martin    748374   57527
# 1      last week tonight trump presidency|"last week ...   2418783   97185
# 2      racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434  146033
# 3      rhett and link|"gmm"|"good mythical morning"|"...    343168   10172
# 4      ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095731  132235
# ...                                                  ...       ...     ...
# 40944  aarons animals|"aarons"|"animals"|"cat"|"cats"...   1685609   38160
# 40945                                             [none]   1064798   60008
# 40946  I gave safiya nygaard a perfect hair makeover ...   1066451   48068
# 40947  Black Panther|"HISHE"|"Marvel"|"Infinity War"|...   5660813  192957
# 40948      call of duty|"cod"|"activision"|"Black Ops 4"  10306119  357079
#
#        dislikes  comment_count  \
# 0          2966          15954
# 1          6146          12703
# 2          5339           8181
# 3           666           2146
# 4          1989          17518
# ...         ...            ...
# 40944      1385           2657
# 40945       382           3936
# 40946      1032           3992
# 40947      2846          13088
# 40948    212976         144795
#
#                                        thumbnail_link  comments_disabled  \
# 0      https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg              False
# 1      https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg              False
# 2      https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg              False
# 3      https://i.ytimg.com/vi/puqaWrEC7tY/default.jpg              False
# 4      https://i.ytimg.com/vi/d380meD0W0M/default.jpg              False
# ...                                               ...                ...
# 40944  https://i.ytimg.com/vi/BZt0qjTWNhw/default.jpg              False
# 40945  https://i.ytimg.com/vi/1h7KV2sjUWY/default.jpg              False
# 40946  https://i.ytimg.com/vi/D6Oy4LfoqsU/default.jpg              False
# 40947  https://i.ytimg.com/vi/oV0zkMe1K8s/default.jpg              False
# 40948  https://i.ytimg.com/vi/ooyjaVdt-jA/default.jpg              False
#
#        ratings_disabled  video_error_or_removed  \
# 0                 False                   False
# 1                 False                   False
# 2                 False                   False
# 3                 False                   False
# 4                 False                   False
# ...                 ...                     ...
# 40944             False                   False
# 40945             False                   False
# 40946             False                   False
# 40947             False                   False
# 40948             False                   False
#
#                                              description
# 0      SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1      One year after the presidential election, John...
# 2      WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 3      Today we find out if Link is a Nickelback amat...
# 4      I know it's been a while since we did this sho...
# ...                                                  ...
# 40944     The Cat Who Caught the Laser - Aaron's Animals
# 40945                                                NaN
# 40946  I had so much fun transforming Safiyas hair in...
# 40947  How Black Panther Should Have EndedWatch More ...
# 40948  Call of Duty: Black Ops 4 Multiplayer raises t...
#
# [40949 rows x 16 columns]

# %%
query_url = f"https://www.googleapis.com/youtube/v3/channels?part=snippet%2CcontentDetails%2Cstatistics&forUsername=RudyMancuso&key={api_key}"

response = requests.get(query_url).json()
pprint(response)
# Out:
# {'etag': 'OAVGFrxjX-KMWxa6bViqzlI7ApA',
#  'items': [{'contentDetails': {'relatedPlaylists': {'favorites': '',
#                                                     'likes': 'LL5jkXpfnBhlDjqh0ir5FsIQ',
#                                                     'uploads': 'UU5jkXpfnBhlDjqh0ir5FsIQ',
#                                                     'watchHistory': 'HL',
#                                                     'watchLater': 'WL'}},
#             'etag': 'POoPY3SmmbY-esz_x6aO55lXE8U',
#             'id': 'UC5jkXpfnBhlDjqh0ir5FsIQ',
#             'kind': 'youtube#channel',
#             'snippet': {'country': 'US',
#                         'customUrl': 'rudymancuso',
#                         'description': 'NEW VIDEOS EVERY WEEK! Make sure you '
#                                        'SUBSCRIBE!\n'
#                                        '\n'
#                                        'Part of the Shots Studios family.',
#                         'localized': {'description': 'NEW VIDEOS EVERY WEEK! '
#                                                      'Make sure you '
#                                                      'SUBSCRIBE!\n'
#                                                      '\n'
#                                                      'Part of the Shots '
#                                                      'Studios family.',
#                                       'title': 'Rudy Mancuso'},
#                         'publishedAt': '2011-09-30T23:14:41Z',
#                         'thumbnails': {'default': {'height': 88,
#                                                    'url': 'https://yt3.ggpht.com/a/AATXAJzWz0NpN_UIynSRDFih0sWmyTM1uQ4CeV9rtJgk3w=s88-c-k-c0xffffffff-no-rj-mo',
#                                                    'width': 88},
#                                        'high': {'height': 800,
#                                                 'url': 'https://yt3.ggpht.com/a/AATXAJzWz0NpN_UIynSRDFih0sWmyTM1uQ4CeV9rtJgk3w=s800-c-k-c0xffffffff-no-rj-mo',
#                                                 'width': 800},
#                                        'medium': {'height': 240,
#                                                   'url': 'https://yt3.ggpht.com/a/AATXAJzWz0NpN_UIynSRDFih0sWmyTM1uQ4CeV9rtJgk3w=s240-c-k-c0xffffffff-no-rj-mo',
#                                                   'width': 240}},
#                         'title': 'Rudy Mancuso'},
#             'statistics': {'commentCount': '0',
#                            'hiddenSubscriberCount': False,
#                            'subscriberCount': '7340000',
#                            'videoCount': '132',
#                            'viewCount': '1292817197'}}],
#  'kind': 'youtube#channelListResponse',
#  'pageInfo': {'resultsPerPage': 5, 'totalResults': 1}}

# %%
channels = youtube_data_df["channel_title"].unique()
channel = []

for i in range(len(channels)):
   channel.append(youtube_data_df.at[(i, "channel_title")])

# %%
channel_list = pd.DataFrame({"Channel": channel})
fake_list = channel_list.iloc[0:5,:]
fake_list
# Out:
#                  Channel
# 0           CaseyNeistat
# 1        LastWeekTonight
# 2           Rudy Mancuso
# 3  Good Mythical Morning
# 4               nigahiga

# %%
video_url = f"https://www.googleapis.com/youtube/v3/videos?part=snippet&id=2kyS6SvSYSE&key={api_key}"
response = requests.get(video_url).json()
pprint(response)
# Out:
# {'etag': '_kkiDKS98JFHC23TnWmsA_RCI0Q',
#  'items': [{'etag': 'aZyOhFipz0QoCn_Vaug5O-gEpYA',
#             'id': '2kyS6SvSYSE',
#             'kind': 'youtube#video',
#             'snippet': {'categoryId': '22',
#                         'channelId': 'UCtinbF-Q-fVthA0qrFQTgXQ',
#                         'channelTitle': 'CaseyNeistat',
#                         'description': "SHANTELL'S CHANNEL - "
#                                        'https://www.youtube.com/shantellmartin\n'
#                                        'CANDICE - https://www.lovebilly.com\n'
#                                        '\n'
#                                        "'Diamond Veins (Blowsom remix)' by "
#                                        'French 79 '
#                                        'http://hyperurl.co/DiamondVeinsRMX\n'
#                                        "'Moon' by Kid Francescoli "
#                                        'http://hyperurl.co/KID_PlayMeAgain\n'
#                                        '\n'
#                                        'filmed this video in 4k on this -- '
#                                        'http://amzn.to/2sTDnRZ\n'
#                                        'with this lens -- '
#                                        'http://amzn.to/2rUJOmD\n'
#                                        'big drone - '
#                                        'http://tinyurl.com/h4ft3oy\n'
#                                        'OTHER GEAR ---  '
#                                        'http://amzn.to/2o3GLX5\n'
#                                        'Sony CAMERA http://amzn.to/2nOBmnv\n'
#                                        'OLD CAMERA; http://amzn.to/2o2cQBT\n'
#                                        'MAIN LENS; http://amzn.to/2od5gBJ\n'
#                                        'BIG SONY CAMERA; '
#                                        'http://amzn.to/2nrdJRO\n'
#                                        'BIG Canon CAMERA; '
#                                        'http://tinyurl.com/jn4q4vz\n'
#                                        'BENDY TRIPOD THING; '
#                                        'http://tinyurl.com/gw3ylz2\n'
#                                        'YOU NEED THIS FOR THE BENDY TRIPOD; '
#                                        'http://tinyurl.com/j8mzzua\n'
#                                        'WIDE LENS; http://tinyurl.com/jkfcm8t\n'
#                                        'MORE EXPENSIVE WIDE LENS; '
#                                        'http://tinyurl.com/zrdgtou\n'
#                                        'SMALL CAMERA; '
#                                        'http://tinyurl.com/hrrzhor\n'
#                                        'MICROPHONE; '
#                                        'http://tinyurl.com/zefm4jy\n'
#                                        'OTHER MICROPHONE; '
#                                        'http://tinyurl.com/jxgpj86\n'
#                                        'OLD DRONE (cheaper but still '
#                                        'great);http://tinyurl.com/zcfmnmd\n'
#                                        '\n'
#                                        'follow me; on '
#                                        'http://instagram.com/caseyneistat\n'
#                                        'on https://www.facebook.com/cneistat\n'
#                                        'on https://twitter.com/CaseyNeistat\n'
#                                        '\n'
#                                        'amazing intro song by '
#                                        'https://soundcloud.com/discoteeth\n'
#                                        '\n'
#                                        'ad disclosure.  THIS IS NOT AN AD.  '
#                                        'not selling or promoting anything.  '
#                                        'but samsung did produce the Shantell '
#                                        "Video as a 'GALAXY PROJECT' which is "
#                                        'an initiative that enables creators '
#                                        'like Shantell and me to make projects '
#                                        'we might otherwise not have the '
#                                        "opportunity to make.  hope that's "
#                                        'clear.  if not ask in the comments and '
#                                        "i'll answer any specifics.",
#                         'liveBroadcastContent': 'none',
#                         'localized': {'description': "SHANTELL'S CHANNEL - "
#                                                      'https://www.youtube.com/shantellmartin\n'
#                                                      'CANDICE - '
#                                                      'https://www.lovebilly.com\n'
#                                                      '\n'
#                                                      "'Diamond Veins (Blowsom "
#                                                      "remix)' by French 79 "
#                                                      'http://hyperurl.co/DiamondVeinsRMX\n'
#                                                      "'Moon' by Kid "
#                                                      'Francescoli '
#                                                      'http://hyperurl.co/KID_PlayMeAgain\n'
#                                                      '\n'
#                                                      'filmed this video in 4k '
#                                                      'on this -- '
#                                                      'http://amzn.to/2sTDnRZ\n'
#                                                      'with this lens -- '
#                                                      'http://amzn.to/2rUJOmD\n'
#                                                      'big drone - '
#                                                      'http://tinyurl.com/h4ft3oy\n'
#                                                      'OTHER GEAR ---  '
#                                                      'http://amzn.to/2o3GLX5\n'
#                                                      'Sony CAMERA '
#                                                      'http://amzn.to/2nOBmnv\n'
#                                                      'OLD CAMERA; '
#                                                      'http://amzn.to/2o2cQBT\n'
#                                                      'MAIN LENS; '
#                                                      'http://amzn.to/2od5gBJ\n'
#                                                      'BIG SONY CAMERA; '
#                                                      'http://amzn.to/2nrdJRO\n'
#                                                      'BIG Canon CAMERA; '
#                                                      'http://tinyurl.com/jn4q4vz\n'
#                                                      'BENDY TRIPOD THING; '
#                                                      'http://tinyurl.com/gw3ylz2\n'
#                                                      'YOU NEED THIS FOR THE '
#                                                      'BENDY TRIPOD; '
#                                                      'http://tinyurl.com/j8mzzua\n'
#                                                      'WIDE LENS; '
#                                                      'http://tinyurl.com/jkfcm8t\n'
#                                                      'MORE EXPENSIVE WIDE '
#                                                      'LENS; '
#                                                      'http://tinyurl.com/zrdgtou\n'
#                                                      'SMALL CAMERA; '
#                                                      'http://tinyurl.com/hrrzhor\n'
#                                                      'MICROPHONE; '
#                                                      'http://tinyurl.com/zefm4jy\n'
#                                                      'OTHER MICROPHONE; '
#                                                      'http://tinyurl.com/jxgpj86\n'
#                                                      'OLD DRONE (cheaper but '
#                                                      'still '
#                                                      'great);http://tinyurl.com/zcfmnmd\n'
#                                                      '\n'
#                                                      'follow me; on '
#                                                      'http://instagram.com/caseyneistat\n'
#                                                      'on '
#                                                      'https://www.facebook.com/cneistat\n'
#                                                      'on '
#                                                      'https://twitter.com/CaseyNeistat\n'
#                                                      '\n'
#                                                      'amazing intro song by '
#                                                      'https://soundcloud.com/discoteeth\n'
#                                                      '\n'
#                                                      'ad disclosure.  THIS IS '
#                                                      'NOT AN AD.  not selling '
#                                                      'or promoting anything.  '
#                                                      'but samsung did produce '
#                                                      'the Shantell Video as a '
#                                                      "'GALAXY PROJECT' which "
#                                                      'is an initiative that '
#                                                      'enables creators like '
#                                                      'Shantell and me to make '
#                                                      'projects we might '
#                                                      'otherwise not have the '
#                                                      'opportunity to make.  '
#                                                      "hope that's clear.  if "
#                                                      'not ask in the comments '
#                                                      "and i'll answer any "
#                                                      'specifics.',
#                                       'title': 'WE WANT TO TALK ABOUT OUR '
#                                                'MARRIAGE'},
#                         'publishedAt': '2017-11-13T17:13:01Z',
#                         'tags': ['SHANtell martin'],
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/2kyS6SvSYSE/hqdefault.jpg',
#                                                 'width': 480},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/2kyS6SvSYSE/mqdefault.jpg',
#                                                   'width': 320},
#                                        'standard': {'height': 480,
#                                                     'url': 'https://i.ytimg.com/vi/2kyS6SvSYSE/sddefault.jpg',
#                                                     'width': 640}},
#                         'title': 'WE WANT TO TALK ABOUT OUR MARRIAGE'}}],
#  'kind': 'youtube#videoListResponse',
#  'pageInfo': {'resultsPerPage': 1, 'totalResults': 1}}

# %%
videos = youtube_data_df["video_id"]
video_id = []

for i in range(len(videos)):
    video_id.append((youtube_data_df.at[(i, "video_id")]))
    
videoid_list = pd.DataFrame({"Video_id": video_id})
vid_list = videoid_list.iloc[0:5, :]
vid_list
# Out:
#       Video_id
# 0  2kyS6SvSYSE
# 1  1ZAPwfrtAFY
# 2  5qpjK5DgCt4
# 3  puqaWrEC7tY
# 4  d380meD0W0M

# %%
vid_list['channel_id'] = ""

for index, row in vid_list.iterrows():
    vidid = row['Video_id']
    video_url = f"https://www.googleapis.com/youtube/v3/videos?part=snippet&id={vidid}&key={api_key}"
    response = requests.get(video_url).json()
    
    
    
    try: 
   
        vid_list.loc[index,'channel_id'] = response['items'][0]['snippet']['channelId']
    
    except:
        
         pass

    

vid_list
# Out:
# C:\Users\baboo\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\baboo\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\baboo\anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
#       Video_id                channel_id
# 0  2kyS6SvSYSE  UCtinbF-Q-fVthA0qrFQTgXQ
# 1  1ZAPwfrtAFY  UC3XTzVzaHQEd30rQbuvCtTQ
# 2  5qpjK5DgCt4  UC5jkXpfnBhlDjqh0ir5FsIQ
# 3  puqaWrEC7tY  UC4PooiX37Pld1T8J5SYT-SQ
# 4  d380meD0W0M  UCSAUGyc_xA8uYzaIVG6MESQ

# %%
vid_list["subscriber_count"] = ""
vid_list["view_count"] = ""
vid_list["video_count"] = ""

for index, row in vid_list.iterrows():
    channel_title = row["channel_id"]
    query_url = f"https://www.googleapis.com/youtube/v3/channels?part=statistics&id={channel_title}&key={api_key}"
    response = requests.get(query_url).json()

    try: 
        vid_list.loc[index,"subscriber_count"] = response["items"][0]["statistics"]["subscriberCount"]
        vid_list.loc[index,"video_count"] = response["items"][0]["statistics"]["videoCount"]
        vid_list.loc[index,"view_count"] = response["items"][0]["statistics"]["viewCount"]
    
    except:
        
        pass
    

vid_list
# Out:
# C:\Users\baboo\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\baboo\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\baboo\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\baboo\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\baboo\anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\baboo\anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# C:\Users\baboo\anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
#       Video_id                channel_id subscriber_count  view_count  \
# 0  2kyS6SvSYSE  UCtinbF-Q-fVthA0qrFQTgXQ         12100000  2833750208
# 1  1ZAPwfrtAFY  UC3XTzVzaHQEd30rQbuvCtTQ          8190000  2571354715
# 2  5qpjK5DgCt4  UC5jkXpfnBhlDjqh0ir5FsIQ          7340000  1292817197
# 3  puqaWrEC7tY  UC4PooiX37Pld1T8J5SYT-SQ         16400000  6490592598
# 4  d380meD0W0M  UCSAUGyc_xA8uYzaIVG6MESQ         21400000  4260488207
#
#   video_count
# 0        1033
# 1         312
# 2         132
# 3        2479
# 4         408
