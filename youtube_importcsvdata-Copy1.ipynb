# %%
import pandas as pd
import os
import csv
from config import api_key
import requests
import json
from pprint import pprint

# %%
csvpath = os.path.join("youtube_video_data.csv")
youtube_data_df = pd.read_csv(csvpath)
youtube_data_df
# Out:
#           video_id trending_date  \
# 0      2kyS6SvSYSE      17.14.11
# 1      1ZAPwfrtAFY      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      puqaWrEC7tY      17.14.11
# 4      d380meD0W0M      17.14.11
# ...            ...           ...
# 40944  BZt0qjTWNhw      18.14.06
# 40945  1h7KV2sjUWY      18.14.06
# 40946  D6Oy4LfoqsU      18.14.06
# 40947  oV0zkMe1K8s      18.14.06
# 40948  ooyjaVdt-jA      18.14.06
#
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 40944                       The Cat Who Caught the Laser
# 40945                         True Facts : Ant Mutualism
# 40946  I GAVE SAFIYA NYGAARD A PERFECT HAIR MAKEOVER ...
# 40947                How Black Panther Should Have Ended
# 40948  Official Call of Duty®: Black Ops 4 — Multipla...
#
#                   channel_title  category_id              publish_time  \
# 0                  CaseyNeistat           22  2017-11-13T17:13:01.000Z
# 1               LastWeekTonight           24  2017-11-13T07:30:00.000Z
# 2                  Rudy Mancuso           23  2017-11-12T19:05:24.000Z
# 3         Good Mythical Morning           24  2017-11-13T11:00:04.000Z
# 4                      nigahiga           24  2017-11-12T18:01:41.000Z
# ...                         ...          ...                       ...
# 40944             AaronsAnimals           15  2018-05-18T13:00:04.000Z
# 40945                  zefrank1           22  2018-05-18T01:00:06.000Z
# 40946                Brad Mondo           24  2018-05-18T17:34:22.000Z
# 40947  How It Should Have Ended            1  2018-05-17T17:00:04.000Z
# 40948              Call of Duty           20  2018-05-17T17:09:38.000Z
#
#                                                     tags     views   likes  \
# 0                                        SHANtell martin    748374   57527
# 1      last week tonight trump presidency|"last week ...   2418783   97185
# 2      racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434  146033
# 3      rhett and link|"gmm"|"good mythical morning"|"...    343168   10172
# 4      ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095731  132235
# ...                                                  ...       ...     ...
# 40944  aarons animals|"aarons"|"animals"|"cat"|"cats"...   1685609   38160
# 40945                                             [none]   1064798   60008
# 40946  I gave safiya nygaard a perfect hair makeover ...   1066451   48068
# 40947  Black Panther|"HISHE"|"Marvel"|"Infinity War"|...   5660813  192957
# 40948      call of duty|"cod"|"activision"|"Black Ops 4"  10306119  357079
#
#        dislikes  comment_count  \
# 0          2966          15954
# 1          6146          12703
# 2          5339           8181
# 3           666           2146
# 4          1989          17518
# ...         ...            ...
# 40944      1385           2657
# 40945       382           3936
# 40946      1032           3992
# 40947      2846          13088
# 40948    212976         144795
#
#                                        thumbnail_link  comments_disabled  \
# 0      https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg              False
# 1      https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg              False
# 2      https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg              False
# 3      https://i.ytimg.com/vi/puqaWrEC7tY/default.jpg              False
# 4      https://i.ytimg.com/vi/d380meD0W0M/default.jpg              False
# ...                                               ...                ...
# 40944  https://i.ytimg.com/vi/BZt0qjTWNhw/default.jpg              False
# 40945  https://i.ytimg.com/vi/1h7KV2sjUWY/default.jpg              False
# 40946  https://i.ytimg.com/vi/D6Oy4LfoqsU/default.jpg              False
# 40947  https://i.ytimg.com/vi/oV0zkMe1K8s/default.jpg              False
# 40948  https://i.ytimg.com/vi/ooyjaVdt-jA/default.jpg              False
#
#        ratings_disabled  video_error_or_removed  \
# 0                 False                   False
# 1                 False                   False
# 2                 False                   False
# 3                 False                   False
# 4                 False                   False
# ...                 ...                     ...
# 40944             False                   False
# 40945             False                   False
# 40946             False                   False
# 40947             False                   False
# 40948             False                   False
#
#                                              description
# 0      SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1      One year after the presidential election, John...
# 2      WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 3      Today we find out if Link is a Nickelback amat...
# 4      I know it's been a while since we did this sho...
# ...                                                  ...
# 40944     The Cat Who Caught the Laser - Aaron's Animals
# 40945                                                NaN
# 40946  I had so much fun transforming Safiyas hair in...
# 40947  How Black Panther Should Have EndedWatch More ...
# 40948  Call of Duty: Black Ops 4 Multiplayer raises t...
#
# [40949 rows x 16 columns]

# %%
like = youtube_data_df["likes"].astype(float)
dislike = youtube_data_df["dislikes"].astype(float)
likes_dislikes_ratio = like / dislike   
likes_dislikes_ratio
youtube_data_df["likes vs dislikes"] = likes_dislikes_ratio
clean_data = youtube_data_df.sort_values("likes vs dislikes", ascending=False)
clean_data
# Out:
#           video_id trending_date  \
# 16369  3rhw4KgcvFM      18.05.02
# 16438  FM_7ZyE0ib4      18.06.02
# 4934   0jmDHoPUGKI      17.08.12
# 15542  4Ek6UCI0YQs      18.01.02
# 147    Q6Usd3_fbq8      17.14.11
# ...            ...           ...
# 28135  UwbO_xb1-Xo      18.05.04
# 28346  UwbO_xb1-Xo      18.06.04
# 28550  9TUBf6l7FBg      18.14.04
# 28751  9TUBf6l7FBg      18.15.04
# 28955  9TUBf6l7FBg      18.16.04
#
#                                                    title  \
# 16369  First Responders Arrive To The Collapsed Floor...
# 16438          Kevin Hart Stopped by Super Bowl Security
# 4934   NSC | Face to Face with the Prescription Opioi...
# 15542  Dan Quayle Speech About Murphy Brown and Famil...
# 147    Improvising in the style of different classica...
# ...                                                  ...
# 28135  KKW BEAUTY: Conceal, Bake, Brighten with Mario...
# 28346  KKW BEAUTY: Conceal, Bake, Brighten with Mario...
# 28550                      Coachella 2018 LIVE Channel 1
# 28751                      Coachella 2018 LIVE Channel 1
# 28955                      Coachella 2018 LIVE Channel 1
#
#                  channel_title  category_id              publish_time  \
# 16369             9-1-1 on FOX           24  2018-02-01T02:00:20.000Z
# 16438               World Eyes           27  2018-02-05T03:48:41.000Z
# 4934   National Safety Council           29  2017-12-05T13:50:17.000Z
# 15542              Kevin Stein           27  2015-09-21T21:46:40.000Z
# 147                  Nahre Sol           10  2017-11-10T04:08:31.000Z
# ...                        ...          ...                       ...
# 28135      Kim Kardashian West           22  2018-03-21T18:42:04.000Z
# 28346      Kim Kardashian West           22  2018-03-21T18:42:04.000Z
# 28550                Coachella           10  2018-04-05T06:48:28.000Z
# 28751                Coachella           10  2018-04-05T06:48:28.000Z
# 28955                Coachella           10  2018-04-05T06:48:28.000Z
#
#                                                     tags     views  likes  \
# 16369  9-1-1|"first responders"|"police"|"firefighter...      1426     14
# 16438                                             [none]     10358     34
# 4934   National Safety Council|"Opioid misuse"|"addic...      1967     19
# 15542  Family Values|"Dan Quayle (US Vice President)"...      2452      2
# 147    improvise classical music|"improvisation"|"cla...      5149    242
# ...                                                  ...       ...    ...
# 28135  Mario Dedivanovic|"KKW BEAUTY"|"CONCEALER"|"CO...   1040664      0
# 28346  Mario Dedivanovic|"KKW BEAUTY"|"CONCEALER"|"CO...   1045731      0
# 28550                                             [none]   3598220      0
# 28751                                             [none]  11137071      0
# 28955                                             [none]  24004779      0
#
#        dislikes  comment_count  \
# 16369         0              0
# 16438         0             14
# 4934          0              3
# 15542         0              0
# 147           0             54
# ...         ...            ...
# 28135         0              0
# 28346         0              0
# 28550         0              0
# 28751         0              2
# 28955         0              3
#
#                                           thumbnail_link  comments_disabled  \
# 16369     https://i.ytimg.com/vi/3rhw4KgcvFM/default.jpg              False
# 16438     https://i.ytimg.com/vi/FM_7ZyE0ib4/default.jpg              False
# 4934      https://i.ytimg.com/vi/0jmDHoPUGKI/default.jpg              False
# 15542     https://i.ytimg.com/vi/4Ek6UCI0YQs/default.jpg               True
# 147       https://i.ytimg.com/vi/Q6Usd3_fbq8/default.jpg              False
# ...                                                  ...                ...
# 28135     https://i.ytimg.com/vi/UwbO_xb1-Xo/default.jpg               True
# 28346     https://i.ytimg.com/vi/UwbO_xb1-Xo/default.jpg               True
# 28550  https://i.ytimg.com/vi/9TUBf6l7FBg/default_liv...              False
# 28751  https://i.ytimg.com/vi/9TUBf6l7FBg/default_liv...              False
# 28955  https://i.ytimg.com/vi/9TUBf6l7FBg/default_liv...              False
#
#        ratings_disabled  video_error_or_removed  \
# 16369             False                   False
# 16438             False                   False
# 4934              False                   False
# 15542             False                   False
# 147               False                   False
# ...                 ...                     ...
# 28135              True                   False
# 28346              True                   False
# 28550              True                   False
# 28751              True                   False
# 28955              True                   False
#
#                                              description  likes vs dislikes
# 16369  First responders arrive to a collapsed floor d...                inf
# 16438  Kevin Hart tried to follow the trophy on the s...                inf
# 4934   Each year 22,000 people die from prescription ...                inf
# 15542                                                NaN                inf
# 147    Here's a video just for fun - I decided to try...                inf
# ...                                                  ...                ...
# 28135  Watch me conceal, bake and brighten with Mario...                NaN
# 28346  Watch me conceal, bake and brighten with Mario...                NaN
# 28550  For more cameras and VR180 immersive experienc...                NaN
# 28751  For more cameras and VR180 immersive experienc...                NaN
# 28955  For more cameras and VR180 immersive experienc...                NaN
#
# [40949 rows x 17 columns]

# %%
query_url = f"https://www.googleapis.com/youtube/v3/channels?part=snippet%2CcontentDetails%2Cstatistics&forUsername=RudyMancuso&key={api_key}"

response = requests.get(query_url).json()
pprint(response)
# Out:
# {'etag': 'snwbm-9Iw3wDRHTJpTGW-tTHDEQ',
#  'items': [{'contentDetails': {'relatedPlaylists': {'favorites': '',
#                                                     'likes': 'LL5jkXpfnBhlDjqh0ir5FsIQ',
#                                                     'uploads': 'UU5jkXpfnBhlDjqh0ir5FsIQ',
#                                                     'watchHistory': 'HL',
#                                                     'watchLater': 'WL'}},
#             'etag': 'Y4ShMkoKW7Ox2rNRWN_jj0Nx09k',
#             'id': 'UC5jkXpfnBhlDjqh0ir5FsIQ',
#             'kind': 'youtube#channel',
#             'snippet': {'country': 'US',
#                         'customUrl': 'rudymancuso',
#                         'description': 'NEW VIDEOS EVERY WEEK! Make sure you '
#                                        'SUBSCRIBE!\n'
#                                        '\n'
#                                        'Part of the Shots Studios family.',
#                         'localized': {'description': 'NEW VIDEOS EVERY WEEK! '
#                                                      'Make sure you '
#                                                      'SUBSCRIBE!\n'
#                                                      '\n'
#                                                      'Part of the Shots '
#                                                      'Studios family.',
#                                       'title': 'Rudy Mancuso'},
#                         'publishedAt': '2011-09-30T23:14:41Z',
#                         'thumbnails': {'default': {'height': 88,
#                                                    'url': 'https://yt3.ggpht.com/a/AATXAJzWz0NpN_UIynSRDFih0sWmyTM1uQ4CeV9rtJgk3w=s88-c-k-c0xffffffff-no-rj-mo',
#                                                    'width': 88},
#                                        'high': {'height': 800,
#                                                 'url': 'https://yt3.ggpht.com/a/AATXAJzWz0NpN_UIynSRDFih0sWmyTM1uQ4CeV9rtJgk3w=s800-c-k-c0xffffffff-no-rj-mo',
#                                                 'width': 800},
#                                        'medium': {'height': 240,
#                                                   'url': 'https://yt3.ggpht.com/a/AATXAJzWz0NpN_UIynSRDFih0sWmyTM1uQ4CeV9rtJgk3w=s240-c-k-c0xffffffff-no-rj-mo',
#                                                   'width': 240}},
#                         'title': 'Rudy Mancuso'},
#             'statistics': {'commentCount': '0',
#                            'hiddenSubscriberCount': False,
#                            'subscriberCount': '7340000',
#                            'videoCount': '132',
#                            'viewCount': '1292728077'}}],
#  'kind': 'youtube#channelListResponse',
#  'pageInfo': {'resultsPerPage': 5, 'totalResults': 1}}

# %%
channels = youtube_data_df["channel_title"].unique()
channel = []

for i in range(len(channels)):
   channel.append(youtube_data_df.at[(i, "channel_title")])

# %%
channel_list = pd.DataFrame({"Channel": channel})
fake_list = channel_list.iloc[0:5,:]
fake_list
# Out:
#                  Channel
# 0           CaseyNeistat
# 1        LastWeekTonight
# 2           Rudy Mancuso
# 3  Good Mythical Morning
# 4               nigahiga

# %%
query_url = f"https://www.googleapis.com/youtube/v3/channels?part=snippet%2CcontentDetails%2Cstatistics&forUsername={channel[16]}&key={api_key}"
response = requests.get(query_url).json()
pprint(response)
# Out:
# {'etag': 'Zs0VGCO2eyRJoApn-a-y0e5v8mM',
#  'items': [{'contentDetails': {'relatedPlaylists': {'favorites': '',
#                                                     'likes': '',
#                                                     'uploads': 'UUjD2KyAEm84yVH8cTilID7Q',
#                                                     'watchHistory': 'HL',
#                                                     'watchLater': 'WL'}},
#             'etag': '8ixy2wlUIqBwRDX0CthJQYhng9Y',
#             'id': 'UCjD2KyAEm84yVH8cTilID7Q',
#             'kind': 'youtube#channel',
#             'snippet': {'country': 'US',
#                         'customUrl': 'cracked',
#                         'description': "America's Only Humor & Video Site, "
#                                        'Since 1958\n'
#                                        '\n'
#                                        'New sketches every week!',
#                         'localized': {'description': "America's Only Humor & "
#                                                      'Video Site, Since 1958\n'
#                                                      '\n'
#                                                      'New sketches every week!',
#                                       'title': 'Cracked'},
#                         'publishedAt': '2006-02-08T22:07:44Z',
#                         'thumbnails': {'default': {'height': 88,
#                                                    'url': 'https://yt3.ggpht.com/a/AATXAJyzVnXFohmPQv9-9WfdACpqa7OnxNeCoc-QFGvO-Q=s88-c-k-c0xffffffff-no-rj-mo',
#                                                    'width': 88},
#                                        'high': {'height': 800,
#                                                 'url': 'https://yt3.ggpht.com/a/AATXAJyzVnXFohmPQv9-9WfdACpqa7OnxNeCoc-QFGvO-Q=s800-c-k-c0xffffffff-no-rj-mo',
#                                                 'width': 800},
#                                        'medium': {'height': 240,
#                                                   'url': 'https://yt3.ggpht.com/a/AATXAJyzVnXFohmPQv9-9WfdACpqa7OnxNeCoc-QFGvO-Q=s240-c-k-c0xffffffff-no-rj-mo',
#                                                   'width': 240}},
#                         'title': 'Cracked'},
#             'statistics': {'commentCount': '0',
#                            'hiddenSubscriberCount': False,
#                            'subscriberCount': '2630000',
#                            'videoCount': '1731',
#                            'viewCount': '911289379'}}],
#  'kind': 'youtube#channelListResponse',
#  'pageInfo': {'resultsPerPage': 5, 'totalResults': 1}}

# %%
fake_list["subscriber_count"] = ""
fake_list["view_count"] = ""
fake_list["video_count"] = ""

for index, row in fake_list.iterrows():
    channel_title = row["Channel"]
    query_url = f"https://www.googleapis.com/youtube/v3/channels?part=statistics&forUsername={channel_title}&key={api_key}"
    response = requests.get(query_url).json()
    #fake_list.loc[index,"subscriber_count"] = response["items"][0]["statistics"]["subscriberCount"]
    #response["items"][0]["statistics"]["subscriberCount"]
    
    try: 
        fake_list.loc[index,"subscriber_count"] = response["items"][0]["statistics"]["subscriberCount"]
    
    except:
        
        pass
    

fake_list
# Out:
# C:\Users\baboo\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\baboo\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\baboo\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\baboo\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\baboo\anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
#                  Channel subscriber_count view_count video_count
# 0           CaseyNeistat         12100000
# 1        LastWeekTonight          8190000
# 2           Rudy Mancuso
# 3  Good Mythical Morning
# 4               nigahiga         21400000

# %%
# video_url = f"https://www.googleapis.com/youtube/v3/videos?part=snippet&id=2kyS6SvSYSE&key={api_key}"
# response = requests.get(video_url).json()
# pprint(response)

# %%
videos = youtube_data_df["video_id"]
video_id = []

for i in range(len(videos)):
    video_id.append((youtube_data_df.at[(i, "video_id")]))
    
videoid_list = pd.DataFrame({"Video_id": video_id})
vid_list = videoid_list.iloc[0:5, :]
vid_list
# Out:
#       Video_id
# 0  2kyS6SvSYSE
# 1  1ZAPwfrtAFY
# 2  5qpjK5DgCt4
# 3  puqaWrEC7tY
# 4  d380meD0W0M

# %%
vid_list['channel_id'] = ""

for index, row in vid_list.iterrows():
    vidid = row['Video_id']
    video_url = f"https://www.googleapis.com/youtube/v3/videos?part=snippet&id={vidid}={api_key}"
    response = requests.get(video_url).json()
    
    
    
#     try: 
   
    vid_list.loc[index,'channel_id'] = response['items'][0]['snippet']['channelId']
    
#     except:
        
#         pass
    

vid_list
# Out:
# C:\Users\baboo\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-a7d220f551d4> in <module>
#      10 #     try:
#      11
# ---> 12     vid_list.loc[index,'channel_id'] = response['items'][0]['snippet']['channelId']
#      13
#      14 #     except:
#
# KeyError: 'items'
